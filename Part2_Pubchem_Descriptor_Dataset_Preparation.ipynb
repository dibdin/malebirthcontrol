# %% [markdown]
# <a href="https://colab.research.google.com/github/dibdin/malebirthcontrol/blob/main/Part2_Pubchem_Descriptor_Dataset_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 2] Descriptor Calculation and Dataset Preparation**
#
# original code credit: Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-10-02 20:36:17--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-10-02 20:36:17--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M   140MB/s    in 0.2s
#
# 2021-10-02 20:36:18 (140 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# --2021-10-02 20:36:18--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2021-10-02 20:36:18--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-10-02 20:36:18 (8.93 MB/s) - ‘padel.sh’ saved [231/231]

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
#   inflating: __MACOSX/PaDEL-Descriptor/._config
#   inflating: PaDEL-Descriptor/PubchemFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._PubchemFingerprinter.xml
#   inflating: PaDEL-Descriptor/ExtendedFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._ExtendedFingerprinter.xml
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprinter.xml
#   inflating: PaDEL-Descriptor/GraphOnlyFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._GraphOnlyFingerprinter.xml
#   inflating: PaDEL-Descriptor/SubstructureFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprinter.xml
#   inflating: PaDEL-Descriptor/Descriptors.xls
#   inflating: __MACOSX/PaDEL-Descriptor/._Descriptors.xls
#    creating: PaDEL-Descriptor/lib/
#   inflating: __MACOSX/PaDEL-Descriptor/._lib
#   inflating: PaDEL-Descriptor/PaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/._PaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/SubstructureFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._SubstructureFingerprintCount.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprintCount.xml
#   inflating: PaDEL-Descriptor/descriptors.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._descriptors.xml
#   inflating: PaDEL-Descriptor/license/lgpl-2.1.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl-2.1.txt
#   inflating: PaDEL-Descriptor/license/LICENSE.txt
#   inflating: __MACOSX/PaDEL-Descriptor/license/._LICENSE.txt
#   inflating: PaDEL-Descriptor/license/README - CDK
#   inflating: __MACOSX/PaDEL-Descriptor/license/._README - CDK
#   inflating: PaDEL-Descriptor/license/lgpl.license
#   inflating: __MACOSX/PaDEL-Descriptor/license/._lgpl.license
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL.jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(4).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(2).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1(1).jar
#   inflating: PaDEL-Descriptor/lib/swing-worker-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._swing-worker-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(3).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(5).jar
#   inflating: PaDEL-Descriptor/lib/jama(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(1).jar
#   inflating: PaDEL-Descriptor/lib/appframework-1.0.3.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._appframework-1.0.3.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(7).jar
#   inflating: PaDEL-Descriptor/lib/vecmath1.2-1.14.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._vecmath1.2-1.14.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(6).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(6).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(2).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(4).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-base-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/xom-1.1.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._xom-1.1.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(5).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(2).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(3).jar
#   inflating: PaDEL-Descriptor/lib/jama(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(7).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(6).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor(1).jar
#   inflating: PaDEL-Descriptor/lib/jama(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(3).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(2).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(3).jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all(1).jar
#   inflating: PaDEL-Descriptor/lib/jama.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama.jar
#   inflating: PaDEL-Descriptor/lib/l2fprod-common-all.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._l2fprod-common-all.jar
#   inflating: PaDEL-Descriptor/lib/jama(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(5).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(1).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(7).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(7).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Descriptor.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Descriptor.jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(4).jar
#   inflating: PaDEL-Descriptor/lib/cdk-1.4.15.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._cdk-1.4.15.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(5).jar
#   inflating: PaDEL-Descriptor/lib/ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-core-2.4.7-SNAPSHOT(1).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(8).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(8).jar
#   inflating: PaDEL-Descriptor/lib/jgrapht-0.6.0(6).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jgrapht-0.6.0(6).jar
#   inflating: PaDEL-Descriptor/lib/jama(2).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(2).jar
#   inflating: PaDEL-Descriptor/lib/jama(3).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._jama(3).jar
#   inflating: PaDEL-Descriptor/lib/commons-cli-1.2(1).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._commons-cli-1.2(1).jar
#   inflating: PaDEL-Descriptor/lib/guava-17.0.jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._guava-17.0.jar
#   inflating: PaDEL-Descriptor/lib/ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._ambit2-smarts-2.4.7-SNAPSHOT(4).jar
#   inflating: PaDEL-Descriptor/lib/libPaDEL-Jobs(5).jar
#   inflating: __MACOSX/PaDEL-Descriptor/lib/._libPaDEL-Jobs(5).jar

# %% [markdown]
# ## upload bioactivity_preprocessed_data_spem1.csv from GitHub

# %% [markdown]
# ### **Convert IC50 to pIC50**
# To allow **IC50** data to be more uniformly distributed, we will convert **IC50** to the negative logarithmic scale which is essentially **-log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
# * Take the IC50 values from the ``standard_value`` column and converts it from nM to M by multiplying the value by 10$^{-9}$
# * Take the molar value and apply -log10
# * Delete the ``standard_value`` column and create a new ``pIC50`` column

# %%
# https://github.com/chaninlab/estrogen-receptor-alpha-qsar/blob/master/02_ER_alpha_RO5.ipynb

import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df_combined.standard_value.describe()

# %%
-np.log10( (10**-9)* 100000000 )

# %%
-np.log10( (10**-9)* 10000000000 )

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %% [markdown]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = norm_value(df_combined)
df_norm

# %%
df_norm.standard_value_norm.describe()

# %%
df_final = pIC50(df_norm)
df_final

# %%
df_final.pIC50.describe()

# %% [markdown]
# ### **Removing the 'intermediate' bioactivity class**
# Here, we will be removing the ``intermediate`` class from our data set.

# %%
df_2class = df_final[df_final.bioactivity_class != 'intermediate']
df_2class

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df_2class_selection = df3[selection]
df_2class_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
df_2class

# %%
! cat molecule.smi | head -5
# Out:
# C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(Cn2nnnc2-c2ccccc2)c2ccccc2)CC1	CHEMBL105460
# C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(Cn2cncn2)c2ccccc2)CC1	CHEMBL105606
# C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(C)(Cn2cnc3ccccc32)c2ccccc2)CC1	CHEMBL105570
# CN(C[C@@H](CCN1CCC2(CC1)C[S+]([O-])c1ccccc12)c1cccc(Cl)c1)S(=O)(=O)c1ccccc1	CHEMBL83338
# C=CCN(C(=O)OCc1ccc([N+](=O)[O-])cc1)C1CCN(CCC(Cn2ncc3ccccc32)c2ccccc2)CC1	CHEMBL325357

# %%
! cat molecule.smi | wc -l
# Out:
# 2644

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL105460 in molecule.smi (1/2644).
# Processing CHEMBL105606 in molecule.smi (2/2644).
# Processing CHEMBL105570 in molecule.smi (3/2644). Average speed: 5.79 s/mol.
# Processing CHEMBL83338 in molecule.smi (4/2644). Average speed: 3.22 s/mol.
# Processing CHEMBL325357 in molecule.smi (5/2644). Average speed: 2.49 s/mol.
# Processing CHEMBL105572 in molecule.smi (6/2644). Average speed: 1.99 s/mol.
# Processing CHEMBL107750 in molecule.smi (7/2644). Average speed: 1.81 s/mol.
# Processing CHEMBL105659 in molecule.smi (8/2644). Average speed: 1.53 s/mol.
# Processing CHEMBL107380 in molecule.smi (9/2644). Average speed: 1.47 s/mol.
# Processing CHEMBL104793 in molecule.smi (10/2644). Average speed: 1.31 s/mol.
# Processing CHEMBL106231 in molecule.smi (11/2644). Average speed: 1.35 s/mol.
# Processing CHEMBL321539 in molecule.smi (12/2644). Average speed: 1.36 s/mol.
# Processing CHEMBL322439 in molecule.smi (13/2644). Average speed: 1.20 s/mol.
# Processing CHEMBL104474 in molecule.smi (14/2644). Average speed: 1.11 s/mol.
# Processing CHEMBL319622 in molecule.smi (15/2644). Average speed: 1.07 s/mol.
# Processing CHEMBL104867 in molecule.smi (16/2644). Average speed: 1.03 s/mol.
# Processing CHEMBL104867 in molecule.smi (17/2644). Average speed: 1.08 s/mol.
# Processing CHEMBL104464 in molecule.smi (18/2644). Average speed: 0.97 s/mol.
# Processing CHEMBL106803 in molecule.smi (19/2644). Average speed: 0.96 s/mol.
# Processing CHEMBL107380 in molecule.smi (20/2644). Average speed: 0.92 s/mol.
# Processing CHEMBL320365 in molecule.smi (21/2644). Average speed: 0.92 s/mol.
# Processing CHEMBL61536 in molecule.smi (23/2644). Average speed: 0.89 s/mol.
# Processing CHEMBL61536 in molecule.smi (22/2644). Average speed: 0.90 s/mol.
# Processing CHEMBL61536 in molecule.smi (24/2644). Average speed: 0.87 s/mol.
# Processing CHEMBL61536 in molecule.smi (25/2644). Average speed: 0.86 s/mol.
# Processing CHEMBL61374 in molecule.smi (26/2644). Average speed: 0.87 s/mol.
# Processing CHEMBL61374 in molecule.smi (27/2644). Average speed: 0.83 s/mol.
# Processing CHEMBL61374 in molecule.smi (28/2644). Average speed: 0.85 s/mol.
# Processing CHEMBL61374 in molecule.smi (29/2644). Average speed: 0.81 s/mol.
# Processing CHEMBL292625 in molecule.smi (31/2644). Average speed: 0.79 s/mol.
# Processing CHEMBL292625 in molecule.smi (30/2644). Average speed: 0.80 s/mol.
# Processing CHEMBL292625 in molecule.smi (32/2644). Average speed: 0.77 s/mol.
# Processing CHEMBL59511 in molecule.smi (33/2644). Average speed: 0.76 s/mol.
# Processing CHEMBL59511 in molecule.smi (34/2644). Average speed: 0.75 s/mol.
# Processing CHEMBL59511 in molecule.smi (35/2644). Average speed: 0.74 s/mol.
# Processing CHEMBL60711 in molecule.smi (36/2644). Average speed: 0.73 s/mol.
# Processing CHEMBL60711 in molecule.smi (37/2644). Average speed: 0.72 s/mol.
# Processing CHEMBL59492 in molecule.smi (38/2644). Average speed: 0.71 s/mol.
# Processing CHEMBL59492 in molecule.smi (39/2644). Average speed: 0.71 s/mol.
# Processing CHEMBL61465 in molecule.smi (40/2644). Average speed: 0.69 s/mol.
# Processing CHEMBL556314 in molecule.smi (41/2644). Average speed: 0.69 s/mol.
# Processing CHEMBL556314 in molecule.smi (42/2644). Average speed: 0.67 s/mol.
# Processing CHEMBL556314 in molecule.smi (43/2644). Average speed: 0.67 s/mol.
# Processing CHEMBL59602 in molecule.smi (44/2644). Average speed: 0.66 s/mol.
# Processing CHEMBL59602 in molecule.smi (45/2644). Average speed: 0.66 s/mol.
# Processing CHEMBL59602 in molecule.smi (46/2644). Average speed: 0.64 s/mol.
# Processing CHEMBL418120 in molecule.smi (47/2644). Average speed: 0.64 s/mol.
# Processing CHEMBL58176 in molecule.smi (48/2644). Average speed: 0.63 s/mol.
# Processing CHEMBL292894 in molecule.smi (49/2644). Average speed: 0.63 s/mol.
# Processing CHEMBL292894 in molecule.smi (50/2644). Average speed: 0.62 s/mol.
# Processing CHEMBL292894 in molecule.smi (51/2644). Average speed: 0.62 s/mol.
# Processing CHEMBL58101 in molecule.smi (52/2644). Average speed: 0.61 s/mol.
# Processing CHEMBL58101 in molecule.smi (53/2644). Average speed: 0.61 s/mol.
# Processing CHEMBL58101 in molecule.smi (54/2644). Average speed: 0.60 s/mol.
# Processing CHEMBL61828 in molecule.smi (55/2644). Average speed: 0.61 s/mol.
# Processing CHEMBL61828 in molecule.smi (56/2644). Average speed: 0.60 s/mol.
# Processing CHEMBL61828 in molecule.smi (57/2644). Average speed: 0.60 s/mol.
# Processing CHEMBL58441 in molecule.smi (58/2644). Average speed: 0.59 s/mol.
# Processing CHEMBL58441 in molecule.smi (59/2644). Average speed: 0.59 s/mol.
# Processing CHEMBL58441 in molecule.smi (60/2644). Average speed: 0.59 s/mol.
# Processing CHEMBL59328 in molecule.smi (61/2644). Average speed: 0.59 s/mol.
# Processing CHEMBL59328 in molecule.smi (62/2644). Average speed: 0.58 s/mol.
# Processing CHEMBL58004 in molecule.smi (63/2644). Average speed: 0.58 s/mol.
# Processing CHEMBL58004 in molecule.smi (65/2644). Average speed: 0.58 s/mol.
# Processing CHEMBL58004 in molecule.smi (64/2644). Average speed: 0.58 s/mol.
# Processing CHEMBL58004 in molecule.smi (66/2644). Average speed: 0.57 s/mol.
# Processing CHEMBL304931 in molecule.smi (67/2644). Average speed: 0.57 s/mol.
# Processing CHEMBL58897 in molecule.smi (68/2644). Average speed: 0.56 s/mol.
# Processing CHEMBL58897 in molecule.smi (70/2644). Average speed: 0.56 s/mol.
# Processing CHEMBL58897 in molecule.smi (69/2644). Average speed: 0.57 s/mol.
# Processing CHEMBL301454 in molecule.smi (71/2644). Average speed: 0.56 s/mol.
# Processing CHEMBL301454 in molecule.smi (72/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL301454 in molecule.smi (73/2644). Average speed: 0.56 s/mol.
# Processing CHEMBL301454 in molecule.smi (74/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL416512 in molecule.smi (75/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL60279 in molecule.smi (76/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL60279 in molecule.smi (77/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL62152 in molecule.smi (78/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL62152 in molecule.smi (79/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL62152 in molecule.smi (81/2644). Average speed: 0.55 s/mol.
# Processing CHEMBL62152 in molecule.smi (80/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL61424 in molecule.smi (82/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL61424 in molecule.smi (83/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL61424 in molecule.smi (84/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL59358 in molecule.smi (85/2644). Average speed: 0.54 s/mol.
# Processing CHEMBL61466 in molecule.smi (86/2644). Average speed: 0.53 s/mol.
# Processing CHEMBL61466 in molecule.smi (87/2644). Average speed: 0.53 s/mol.
# Processing CHEMBL61466 in molecule.smi (88/2644). Average speed: 0.53 s/mol.
# Processing CHEMBL59285 in molecule.smi (89/2644). Average speed: 0.53 s/mol.
# Processing CHEMBL294271 in molecule.smi (90/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL294271 in molecule.smi (91/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL61373 in molecule.smi (92/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL61373 in molecule.smi (94/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL61373 in molecule.smi (93/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL61373 in molecule.smi (96/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL61373 in molecule.smi (95/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL58109 in molecule.smi (98/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL58109 in molecule.smi (97/2644). Average speed: 0.52 s/mol.
# Processing CHEMBL293900 in molecule.smi (100/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL58109 in molecule.smi (99/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL293900 in molecule.smi (102/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL293900 in molecule.smi (101/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL60225 in molecule.smi (104/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL60589 in molecule.smi (103/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL60225 in molecule.smi (106/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL60225 in molecule.smi (105/2644). Average speed: 0.51 s/mol.
# Processing CHEMBL59101 in molecule.smi (108/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL59101 in molecule.smi (107/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL433635 in molecule.smi (110/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL59101 in molecule.smi (109/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL58248 in molecule.smi (112/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL433635 in molecule.smi (111/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL58248 in molecule.smi (114/2644). Average speed: 0.50 s/mol.
# Processing CHEMBL58248 in molecule.smi (113/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL58387 in molecule.smi (116/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL58387 in molecule.smi (115/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL58387 in molecule.smi (117/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL311795 in molecule.smi (118/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL352514 in molecule.smi (119/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL81252 in molecule.smi (120/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL82786 in molecule.smi (122/2644). Average speed: 0.49 s/mol.
# Processing CHEMBL84268 in molecule.smi (121/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL81926 in molecule.smi (124/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL311532 in molecule.smi (123/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL2114183 in molecule.smi (126/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL81719 in molecule.smi (125/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL312945 in molecule.smi (128/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL353330 in molecule.smi (127/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL368637 in molecule.smi (129/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL309657 in molecule.smi (130/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL311248 in molecule.smi (132/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL83823 in molecule.smi (131/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL353331 in molecule.smi (133/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL353331 in molecule.smi (134/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL79667 in molecule.smi (135/2644). Average speed: 0.48 s/mol.
# Processing CHEMBL174304 in molecule.smi (136/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL311549 in molecule.smi (137/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL82879 in molecule.smi (138/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL421527 in molecule.smi (139/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL79930 in molecule.smi (140/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL172551 in molecule.smi (141/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL83057 in molecule.smi (143/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL311052 in molecule.smi (142/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL172371 in molecule.smi (144/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL82048 in molecule.smi (145/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL435538 in molecule.smi (147/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL79622 in molecule.smi (146/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL432360 in molecule.smi (149/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL80043 in molecule.smi (148/2644). Average speed: 0.47 s/mol.
# Processing CHEMBL172854 in molecule.smi (151/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL82880 in molecule.smi (150/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL84029 in molecule.smi (152/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL313216 in molecule.smi (153/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL311261 in molecule.smi (154/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL85086 in molecule.smi (155/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL421342 in molecule.smi (156/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL81245 in molecule.smi (157/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL440137 in molecule.smi (158/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL83335 in molecule.smi (160/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL435727 in molecule.smi (159/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL430818 in molecule.smi (161/2644). Average speed: 0.46 s/mol.
# Processing CHEMBL79504 in molecule.smi (162/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL83338 in molecule.smi (163/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL2114185 in molecule.smi (164/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL79770 in molecule.smi (165/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL174457 in molecule.smi (167/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL84309 in molecule.smi (166/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL84351 in molecule.smi (168/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL79930 in molecule.smi (169/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL83773 in molecule.smi (170/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL173095 in molecule.smi (171/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL310645 in molecule.smi (172/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL82168 in molecule.smi (173/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL310106 in molecule.smi (174/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL79907 in molecule.smi (175/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL432182 in molecule.smi (176/2644). Average speed: 0.45 s/mol.
# Processing CHEMBL79315 in molecule.smi (178/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL309922 in molecule.smi (177/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL83113 in molecule.smi (180/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL79530 in molecule.smi (179/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL431009 in molecule.smi (181/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL445836 in molecule.smi (183/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL2114184 in molecule.smi (182/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL170892 in molecule.smi (184/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL310369 in molecule.smi (186/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL175327 in molecule.smi (185/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL309619 in molecule.smi (187/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL309447 in molecule.smi (188/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL93168 in molecule.smi (189/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL327241 in molecule.smi (190/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL328260 in molecule.smi (191/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL330285 in molecule.smi (192/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL327354 in molecule.smi (193/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL328373 in molecule.smi (194/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL93851 in molecule.smi (195/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL92133 in molecule.smi (197/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL329813 in molecule.smi (196/2644). Average speed: 0.44 s/mol.
# Processing CHEMBL327898 in molecule.smi (199/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL329107 in molecule.smi (198/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL430867 in molecule.smi (201/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93961 in molecule.smi (200/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93691 in molecule.smi (202/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL96217 in molecule.smi (203/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL330065 in molecule.smi (204/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93229 in molecule.smi (205/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL94179 in molecule.smi (206/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93457 in molecule.smi (207/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL92861 in molecule.smi (208/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93887 in molecule.smi (209/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL327801 in molecule.smi (211/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL315159 in molecule.smi (210/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL406552 in molecule.smi (213/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL90015 in molecule.smi (212/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL329417 in molecule.smi (215/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93277 in molecule.smi (214/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL441635 in molecule.smi (216/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL430905 in molecule.smi (217/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL329382 in molecule.smi (218/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL329893 in molecule.smi (219/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL93139 in molecule.smi (220/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL91697 in molecule.smi (221/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL327392 in molecule.smi (222/2644). Average speed: 0.43 s/mol.
# Processing CHEMBL327540 in molecule.smi (223/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL327478 in molecule.smi (224/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL327800 in molecule.smi (225/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL94032 in molecule.smi (226/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL93644 in molecule.smi (227/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL329555 in molecule.smi (228/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL93625 in molecule.smi (229/2644). Average speed: 0.42 s/mol.
# Processing CHEMBL94182 in molecule.smi (230/2644). Average speed: 0.42 s/mol.
# Processing CHEMB
ecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Sep 24 16:42 padel.sh
# -rw-r--r-- 1 root root 25768637 Sep 24 16:42 padel.zip
# drwxr-xr-x 1 root root     4096 Sep 16 13:40 sample_data

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df_2class_X = pd.read_csv('descriptors_output.csv')

# %%
df_2class_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL105606           1  ...             0             0
# 1      CHEMBL105460           1  ...             0             0
# 2      CHEMBL105570           1  ...             0             0
# 3       CHEMBL83338           1  ...             0             0
# 4      CHEMBL105572           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 2639  CHEMBL3577945           1  ...             0             0
# 2640    CHEMBL41275           1  ...             0             0
# 2641  CHEMBL4470701           1  ...             0             0
# 2642  CHEMBL4457723           1  ...             0             0
# 2643  CHEMBL4442783           1  ...             0             0
#
# [2644 rows x 882 columns]

# %%
df_2class_X = df_2class_X.drop(columns=['Name'])
df_2class_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 2639           1           1  ...             0             0
# 2640           1           1  ...             0             0
# 2641           1           1  ...             0             0
# 2642           1           1  ...             0             0
# 2643           1           1  ...             0             0
#
# [2644 rows x 881 columns]

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df_2class_Y = df3['pIC50']
df_2class_Y
# Out:
# 0       6.474955
# 1       7.552842
# 2       8.000000
# 3       7.455932
# 4       7.823909
#           ...
# 2639    6.153045
# 2640    8.619789
# 2641    6.721246
# 2642    6.542118
# 2643    6.107905
# Name: pIC50, Length: 2644, dtype: float64

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df_2class_X,df_2class_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.474955
# 1              1           1           1  ...             0             0  7.552842
# 2              1           1           1  ...             0             0  8.000000
# 3              1           1           1  ...             0             0  7.455932
# 4              1           1           1  ...             0             0  7.823909
# ...          ...         ...         ...  ...           ...           ...       ...
# 2639           1           1           1  ...             0             0  6.153045
# 2640           1           1           1  ...             0             0  8.619789
# 2641           1           1           1  ...             0             0  6.721246
# 2642           1           1           1  ...             0             0  6.542118
# 2643           1           1           1  ...             0             0  6.107905
#
# [2644 rows x 882 columns]

# %%
dataset3.to_csv('bioactivity_data_spem1_correct_combined_pubchem_fp.csv', index=False)

# %% [markdown]
# # **Let's download the CSV file to your local computer for the Part 3B (Model Building).**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! cp bioactivity_data_spem1_correct_combined_pubchem_fp.csv "/content/gdrive/My Drive/Colab Notebooks/databirthcontrol"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/databirthcontrol"
# Out:
# bioactivity_CCR5_lipinski_pIC50_combined.csv
# bioactivity_data_CCR5_correct_combined_pubchem_fp.csv
# bioactivity_data_CCR5.csv
# bioactivity_preprocessed_data_CCR5.csv
